# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values (data cleaned in previous notebook) and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Get the number of input features
input_dim = X_train.shape[1]

# Function to create and compile the neural network
def create_model(hp):
    
    # Create a new model
    nn_model = tf.keras.models.Sequential()
    
    # Choose activation function for hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Add first hidden layer with hyperparameter-tuned settings
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1, 
        max_value=10, 
        step=2), 
        activation=activation,
        
        # Added L2 regularization to prevent overfitting
        kernel_regularizer=tf.keras.regularizers.l2(0.01),
        input_dim=input_dim))
    
    # Added Dropout layer to prevent overfitting
    nn_model.add(tf.keras.layers.Dropout(0.5))
    
    # Add second hidden layer with 10 neurons
    nn_model.add(tf.keras.layers.Dense(units=10, activation=activation))
    
    # Add output layer for binary classification
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "Precision", "Recall"]) 
    
    # Return compiled model
    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Initialize EarlyStopping callback to monitor the validation loss
# Training will stop if the validation loss doesn't improve for 3 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Trial 21 Complete [00h 00m 02s]
# val_accuracy: 0.6483180522918701
#
# Best val_accuracy So Far: 0.7767584323883057
# Total elapsed time: 00h 00m 42s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 9,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0013'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 81
#
#  dropout (Dropout)           (None, 9)                 0
#
#  dense_1 (Dense)             (None, 10)                100
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 192 (768.00 Byte)
# Trainable params: 192 (768.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.8073 - precision: 0.7944 - recall: 0.6746
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4474 - accuracy: 0.8104 - precision: 0.8137 - recall: 0.6587
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4494 - accuracy: 0.8124 - precision: 0.8129 - recall: 0.6667
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4520 - accuracy: 0.8186 - precision: 0.8311 - recall: 0.6640
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4524 - accuracy: 0.8073 - precision: 0.7981 - recall: 0.6693
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.8094 - precision: 0.8051 - recall: 0.6667
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4656 - accuracy: 0.8094 - precision: 0.8131 - recall: 0.6561
# Epoch 8/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8053 - precision: 0.8086 - recall: 0.6481
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.8053 - precision: 0.8006 - recall: 0.6587
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.8135 - precision: 0.8176 - recall: 0.6640
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.8063 - precision: 0.8052 - recall: 0.6561
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.8104 - precision: 0.8137 - recall: 0.6587
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4475 - accuracy: 0.8124 - precision: 0.8089 - recall: 0.6720
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.8094 - precision: 0.8091 - recall: 0.6614
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.8084 - precision: 0.8025 - recall: 0.6667
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4453 - accuracy: 0.8196 - precision: 0.8170 - recall: 0.6852
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8165 - precision: 0.8278 - recall: 0.6614
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.8135 - precision: 0.8076 - recall: 0.6772
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.8104 - precision: 0.8117 - recall: 0.6614
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4428 - accuracy: 0.8135 - precision: 0.8135 - recall: 0.6693
# Epoch 21/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.8104 - precision: 0.8077 - recall: 0.6667
# Epoch 22/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.8114 - precision: 0.8123 - recall: 0.6640
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.8053 - precision: 0.7913 - recall: 0.6720
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8053 - precision: 0.8006 - recall: 0.6587
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.8012 - precision: 0.8000 - recall: 0.6455
# Epoch 26/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.8155 - precision: 0.8167 - recall: 0.6720
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.8043 - precision: 0.8079 - recall: 0.6455
# Epoch 28/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4443 - accuracy: 0.8135 - precision: 0.8261 - recall: 0.6534
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4524 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.6481
# Epoch 30/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.8073 - precision: 0.8098 - recall: 0.6534
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.8022 - precision: 0.8007 - recall: 0.6481
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.8114 - precision: 0.8123 - recall: 0.6640
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8053 - precision: 0.8148 - recall: 0.6402
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.8084 - precision: 0.8167 - recall: 0.6481
# Epoch 35/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.8104 - precision: 0.8221 - recall: 0.6481
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8124 - precision: 0.8149 - recall: 0.6640
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4454 - accuracy: 0.8104 - precision: 0.8137 - recall: 0.6587
# Epoch 38/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.8114 - precision: 0.8185 - recall: 0.6561
# Epoch 39/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8196 - precision: 0.8295 - recall: 0.6693
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4495 - accuracy: 0.8104 - precision: 0.8137 - recall: 0.6587
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4478 - accuracy: 0.8012 - precision: 0.7961 - recall: 0.6508
# Epoch 42/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4488 - accuracy: 0.8073 - precision: 0.8140 - recall: 0.6481
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.8084 - precision: 0.8167 - recall: 0.6481
# Epoch 44/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4477 - accuracy: 0.8135 - precision: 0.8197 - recall: 0.6614
# Epoch 45/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4507 - accuracy: 0.8094 - precision: 0.8194 - recall: 0.6481
# Epoch 46/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4435 - accuracy: 0.8104 - precision: 0.8077 - recall: 0.6667
# Epoch 47/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4454 - accuracy: 0.8094 - precision: 0.8051 - recall: 0.6667
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.8165 - precision: 0.8257 - recall: 0.6640
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4520 - accuracy: 0.8094 - precision: 0.8259 - recall: 0.6402
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.8094 - precision: 0.8173 - recall: 0.6508
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8094 - precision: 0.8091 - recall: 0.6614
# Epoch 52/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4433 - accuracy: 0.8145 - precision: 0.8182 - recall: 0.6667
# Epoch 53/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4474 - accuracy: 0.8094 - precision: 0.8111 - recall: 0.6587
# Epoch 54/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.8175 - precision: 0.8373 - recall: 0.6534
# Epoch 55/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.8165 - precision: 0.8367 - recall: 0.6508
# Epoch 56/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4532 - accuracy: 0.8073 - precision: 0.8039 - recall: 0.6614
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4481 - accuracy: 0.8073 - precision: 0.8098 - recall: 0.6534
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.8114 - precision: 0.8294 - recall: 0.6429
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.8073 - precision: 0.8098 - recall: 0.6534
# Epoch 60/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.8053 - precision: 0.8066 - recall: 0.6508
# Epoch 61/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4444 - accuracy: 0.8094 - precision: 0.8152 - recall: 0.6534
# Epoch 62/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8104 - precision: 0.8179 - recall: 0.6534
# Epoch 63/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.8114 - precision: 0.8206 - recall: 0.6534
# Epoch 64/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8063 - precision: 0.8113 - recall: 0.6481
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4397 - accuracy: 0.8094 - precision: 0.8237 - recall: 0.6429
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8186 - precision: 0.8289 - recall: 0.6667
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.8135 - precision: 0.8261 - recall: 0.6534
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4524 - accuracy: 0.8073 - precision: 0.8058 - recall: 0.6587
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4479 - accuracy: 0.8145 - precision: 0.8379 - recall: 0.6429
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.8124 - precision: 0.8345 - recall: 0.6402
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4422 - accuracy: 0.8043 - precision: 0.7906 - recall: 0.6693
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8124 - precision: 0.8345 - recall: 0.6402
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.8094 - precision: 0.8131 - recall: 0.6561
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.6481
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.8135 - precision: 0.8374 - recall: 0.6402
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.8073 - precision: 0.8140 - recall: 0.6481
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.8063 - precision: 0.8113 - recall: 0.6481
# Epoch 78/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8063 - precision: 0.8133 - recall: 0.6455
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.8114 - precision: 0.8339 - recall: 0.6376
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4580 - accuracy: 0.8124 - precision: 0.8233 - recall: 0.6534
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.8114 - precision: 0.8271 - recall: 0.6455
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4438 - accuracy: 0.8073 - precision: 0.8270 - recall: 0.6323
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.8043 - precision: 0.8121 - recall: 0.6402
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.8186 - precision: 0.8268 - recall: 0.6693
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.8165 - precision: 0.8278 - recall: 0.6614
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.8175 - precision: 0.8396 - recall: 0.6508
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4459 - accuracy: 0.8053 - precision: 0.8026 - recall: 0.6561
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.8145 - precision: 0.8289 - recall: 0.6534
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8165 - precision: 0.8414 - recall: 0.6455
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.8145 - precision: 0.8267 - recall: 0.6561
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.8084 - precision: 0.8231 - recall: 0.6402
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4415 - accuracy: 0.8104 - precision: 0.8265 - recall: 0.6429
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4427 - accuracy: 0.8124 - precision: 0.8299 - recall: 0.6455
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.8186 - precision: 0.8378 - recall: 0.6561
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.8124 - precision: 0.8129 - recall: 0.6667
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.8084 - precision: 0.8125 - recall: 0.6534
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4360 - accuracy: 0.8124 - precision: 0.8129 - recall: 0.6667
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.8063 - precision: 0.8154 - recall: 0.6429
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.8084 - precision: 0.8167 - recall: 0.6481
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.8094 - precision: 0.8215 - recall: 0.6455

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.4832 - accuracy: 0.7859 - precision: 0.8095 - recall: 0.5574 - 25ms/epoch - 2ms/step
# Loss: 0.4831599295139313, Accuracy: 0.785932719707489, Precision: 0.8095238208770752, Recall: 0.5573770403862

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[189  16]
#  [ 54  68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84       205
#            1       0.81      0.56      0.66       122
#
#     accuracy                           0.79       327
#    macro avg       0.79      0.74      0.75       327
# weighted avg       0.79      0.79      0.78       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod1_opt1b.keras')
