# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values (data cleaned in previous notebook) and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Get the number of input features
input_dim = X_train.shape[1]

# Function to create and compile the neural network
def create_model(hp):
    
    # Create a new model
    nn_model = tf.keras.models.Sequential()
    
    # Choose activation function for hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Add first hidden layer with hyperparameter-tuned settings
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1, 
        max_value=10, 
        step=2), 
        activation=activation,
        
        # Removed L2 regularization
        # kernel_regularizer=tf.keras.regularizers.l2(0.01),
        input_dim=input_dim))
    
    # Removed Dropout layer
    # nn_model.add(tf.keras.layers.Dropout(0.5))
    
    # Add second hidden layer with 10 neurons
    nn_model.add(tf.keras.layers.Dense(units=10, activation=activation))
    
    # Add output layer for binary classification
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "Precision", "Recall"]) 
    
    # Return compiled model
    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Removed EarlyStopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
# Increased epochs to 40
tuner.search(X_train_scaled, y_train, epochs=40, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 21 Complete [00h 00m 02s]
# val_accuracy: 0.7400611639022827
#
# Best val_accuracy So Far: 0.8012232184410095
# Total elapsed time: 00h 00m 40s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0013'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 81
#
#  dense_1 (Dense)             (None, 10)                100
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 192 (768.00 Byte)
# Trainable params: 192 (768.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 1ms/step - loss: 0.4518 - accuracy: 0.7951 - precision: 0.7479 - recall: 0.7063
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.7971 - precision: 0.7493 - recall: 0.7116
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.8012 - precision: 0.7563 - recall: 0.7143
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.8002 - precision: 0.7542 - recall: 0.7143
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.8022 - precision: 0.7556 - recall: 0.7196
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4368 - accuracy: 0.8033 - precision: 0.7577 - recall: 0.7196
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.8043 - precision: 0.7583 - recall: 0.7222
# Epoch 8/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.8043 - precision: 0.7598 - recall: 0.7196
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.8063 - precision: 0.7640 - recall: 0.7196
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4305 - accuracy: 0.8094 - precision: 0.7645 - recall: 0.7302
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4288 - accuracy: 0.8114 - precision: 0.7688 - recall: 0.7302
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4268 - accuracy: 0.8145 - precision: 0.7737 - recall: 0.7328
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4256 - accuracy: 0.8135 - precision: 0.7686 - recall: 0.7381
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.8135 - precision: 0.7671 - recall: 0.7407
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8165 - precision: 0.7735 - recall: 0.7407
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4218 - accuracy: 0.8145 - precision: 0.7722 - recall: 0.7354
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.8114 - precision: 0.7644 - recall: 0.7381
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8145 - precision: 0.7722 - recall: 0.7354
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8135 - precision: 0.7701 - recall: 0.7354
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4183 - accuracy: 0.8145 - precision: 0.7737 - recall: 0.7328
# Epoch 21/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4182 - accuracy: 0.8145 - precision: 0.7753 - recall: 0.7302
# Epoch 22/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8175 - precision: 0.7787 - recall: 0.7354
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4165 - accuracy: 0.8145 - precision: 0.7722 - recall: 0.7354
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8206 - precision: 0.7837 - recall: 0.7381
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8206 - precision: 0.7837 - recall: 0.7381
# Epoch 26/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8206 - precision: 0.7837 - recall: 0.7381
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4139 - accuracy: 0.8216 - precision: 0.7925 - recall: 0.7275
# Epoch 28/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8206 - precision: 0.7902 - recall: 0.7275
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.8206 - precision: 0.7869 - recall: 0.7328
# Epoch 30/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4121 - accuracy: 0.8216 - precision: 0.7942 - recall: 0.7249
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4120 - accuracy: 0.8236 - precision: 0.8006 - recall: 0.7222
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8247 - precision: 0.8012 - recall: 0.7249
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4107 - accuracy: 0.8267 - precision: 0.8077 - recall: 0.7222
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8247 - precision: 0.8029 - recall: 0.7222
# Epoch 35/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4102 - accuracy: 0.8277 - precision: 0.8083 - recall: 0.7249
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4096 - accuracy: 0.8267 - precision: 0.8114 - recall: 0.7169
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8277 - precision: 0.8101 - recall: 0.7222
# Epoch 38/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8277 - precision: 0.8138 - recall: 0.7169
# Epoch 39/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8298 - precision: 0.8207 - recall: 0.7143
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4082 - accuracy: 0.8298 - precision: 0.8207 - recall: 0.7143
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8287 - precision: 0.8182 - recall: 0.7143
# Epoch 42/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4072 - accuracy: 0.8277 - precision: 0.8196 - recall: 0.7090
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4069 - accuracy: 0.8287 - precision: 0.8201 - recall: 0.7116
# Epoch 44/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8298 - precision: 0.8246 - recall: 0.7090
# Epoch 45/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8267 - precision: 0.8133 - recall: 0.7143
# Epoch 46/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4058 - accuracy: 0.8308 - precision: 0.8252 - recall: 0.7116
# Epoch 47/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4058 - accuracy: 0.8308 - precision: 0.8313 - recall: 0.7037
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8287 - precision: 0.8323 - recall: 0.6958
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8298 - precision: 0.8266 - recall: 0.7063
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8318 - precision: 0.8360 - recall: 0.7011
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8308 - precision: 0.8354 - recall: 0.6984
# Epoch 52/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4039 - accuracy: 0.8308 - precision: 0.8333 - recall: 0.7011
# Epoch 53/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4035 - accuracy: 0.8318 - precision: 0.8360 - recall: 0.7011
# Epoch 54/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8338 - precision: 0.8435 - recall: 0.6984
# Epoch 55/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4033 - accuracy: 0.8318 - precision: 0.8360 - recall: 0.7011
# Epoch 56/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4027 - accuracy: 0.8298 - precision: 0.8328 - recall: 0.6984
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8338 - precision: 0.8457 - recall: 0.6958
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8369 - precision: 0.8516 - recall: 0.6984
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8338 - precision: 0.8457 - recall: 0.6958
# Epoch 60/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8318 - precision: 0.8381 - recall: 0.6984
# Epoch 61/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4016 - accuracy: 0.8359 - precision: 0.8511 - recall: 0.6958
# Epoch 62/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4014 - accuracy: 0.8359 - precision: 0.8466 - recall: 0.7011
# Epoch 63/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8359 - precision: 0.8511 - recall: 0.6958
# Epoch 64/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4005 - accuracy: 0.8359 - precision: 0.8511 - recall: 0.6958
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4011 - accuracy: 0.8338 - precision: 0.8435 - recall: 0.6984
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4004 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8328 - precision: 0.8386 - recall: 0.7011
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3998 - accuracy: 0.8369 - precision: 0.8562 - recall: 0.6931
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3989 - accuracy: 0.8359 - precision: 0.8534 - recall: 0.6931
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8369 - precision: 0.8562 - recall: 0.6931
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.8338 - precision: 0.8479 - recall: 0.6931
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3987 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8338 - precision: 0.8479 - recall: 0.6931
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8359 - precision: 0.8534 - recall: 0.6931
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8369 - precision: 0.8562 - recall: 0.6931
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.8379 - precision: 0.8638 - recall: 0.6878
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8349 - precision: 0.8484 - recall: 0.6958
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8369 - precision: 0.8562 - recall: 0.6931
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.8338 - precision: 0.8502 - recall: 0.6905
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8338 - precision: 0.8502 - recall: 0.6905
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8359 - precision: 0.8581 - recall: 0.6878
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8349 - precision: 0.8506 - recall: 0.6931
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8338 - precision: 0.8479 - recall: 0.6931
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3968 - accuracy: 0.8349 - precision: 0.8553 - recall: 0.6878
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3966 - accuracy: 0.8338 - precision: 0.8502 - recall: 0.6905
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3961 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3967 - accuracy: 0.8338 - precision: 0.8502 - recall: 0.6905
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3962 - accuracy: 0.8328 - precision: 0.8474 - recall: 0.6905
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3963 - accuracy: 0.8328 - precision: 0.8520 - recall: 0.6852
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3959 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3961 - accuracy: 0.8338 - precision: 0.8502 - recall: 0.6905
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.4669 - accuracy: 0.7737 - precision: 0.7609 - recall: 0.5738 - 232ms/epoch - 21ms/step
# Loss: 0.46693500876426697, Accuracy: 0.7737002968788147, Precision: 0.760869562625885, Recall: 0.5737704634666443

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[183  22]
#  [ 52  70]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83       205
#            1       0.76      0.57      0.65       122
#
#     accuracy                           0.77       327
#    macro avg       0.77      0.73      0.74       327
# weighted avg       0.77      0.77      0.77       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod1_opt4.keras')
