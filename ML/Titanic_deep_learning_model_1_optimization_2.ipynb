# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values (data cleaned in previous notebook) and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Get the number of input features
input_dim = X_train.shape[1]

# Function to create and compile the neural network
def create_model(hp):
    
    # Create a new model
    nn_model = tf.keras.models.Sequential()
    
    # Choose activation function for hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Add first hidden layer with hyperparameter-tuned settings
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1, 
        max_value=10, 
        step=2), 
        activation=activation,
        
        # Removed L2 regularization
        # kernel_regularizer=tf.keras.regularizers.l2(0.01),
        input_dim=input_dim))
    
    # Added Dropout layer to prevent overfitting
    nn_model.add(tf.keras.layers.Dropout(0.5))
    
    # Add second hidden layer with 10 neurons
    nn_model.add(tf.keras.layers.Dense(units=10, activation=activation))
    
    # Add output layer for binary classification
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "Precision", "Recall"]) 
    
    # Return compiled model
    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Initialize EarlyStopping callback to monitor the validation loss
# Training will stop if the validation loss doesn't improve for 3 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Trial 20 Complete [00h 00m 02s]
# val_accuracy: 0.7003058195114136
#
# Best val_accuracy So Far: 0.7798165082931519
# Total elapsed time: 00h 00m 39s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 3,
#  'tuner/bracket': 2,
#  'tuner/round': 1,
#  'tuner/trial_id': '0010'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 81
#
#  dropout (Dropout)           (None, 9)                 0
#
#  dense_1 (Dense)             (None, 10)                100
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 192 (768.00 Byte)
# Trainable params: 192 (768.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 1ms/step - loss: 0.5583 - accuracy: 0.7105 - precision: 0.6754 - recall: 0.4788
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5529 - accuracy: 0.7350 - precision: 0.7049 - recall: 0.5370
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.7217 - precision: 0.6966 - recall: 0.4921
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5499 - accuracy: 0.7085 - precision: 0.6704 - recall: 0.4788
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5463 - accuracy: 0.7105 - precision: 0.6610 - recall: 0.5106
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5443 - accuracy: 0.7258 - precision: 0.6926 - recall: 0.5185
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5531 - accuracy: 0.7176 - precision: 0.6810 - recall: 0.5026
# Epoch 8/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5372 - accuracy: 0.7268 - precision: 0.7165 - recall: 0.4815
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7441 - precision: 0.7167 - recall: 0.5556
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5211 - accuracy: 0.7288 - precision: 0.6931 - recall: 0.5317
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5390 - accuracy: 0.7278 - precision: 0.6920 - recall: 0.5291
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5320 - accuracy: 0.7329 - precision: 0.6973 - recall: 0.5423
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5319 - accuracy: 0.7299 - precision: 0.7025 - recall: 0.5185
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5174 - accuracy: 0.7309 - precision: 0.6827 - recall: 0.5635
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5172 - accuracy: 0.7462 - precision: 0.7129 - recall: 0.5714
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5149 - accuracy: 0.7390 - precision: 0.7020 - recall: 0.5608
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5118 - accuracy: 0.7421 - precision: 0.7049 - recall: 0.5688
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5026 - accuracy: 0.7533 - precision: 0.7112 - recall: 0.6058
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5070 - accuracy: 0.7482 - precision: 0.7162 - recall: 0.5741
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5147 - accuracy: 0.7584 - precision: 0.7196 - recall: 0.6111
# Epoch 21/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5095 - accuracy: 0.7492 - precision: 0.7245 - recall: 0.5635
# Epoch 22/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5067 - accuracy: 0.7482 - precision: 0.7079 - recall: 0.5899
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5105 - accuracy: 0.7472 - precision: 0.7044 - recall: 0.5926
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5002 - accuracy: 0.7717 - precision: 0.7406 - recall: 0.6270
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5091 - accuracy: 0.7421 - precision: 0.6959 - recall: 0.5873
# Epoch 26/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4897 - accuracy: 0.7757 - precision: 0.7500 - recall: 0.6270
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4908 - accuracy: 0.7717 - precision: 0.7452 - recall: 0.6190
# Epoch 28/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4967 - accuracy: 0.7737 - precision: 0.7468 - recall: 0.6243
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4938 - accuracy: 0.7737 - precision: 0.7422 - recall: 0.6323
# Epoch 30/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.7778 - precision: 0.7454 - recall: 0.6429
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5000 - accuracy: 0.7554 - precision: 0.7156 - recall: 0.6058
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.7788 - precision: 0.7347 - recall: 0.6667
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5016 - accuracy: 0.7594 - precision: 0.7219 - recall: 0.6111
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4957 - accuracy: 0.7778 - precision: 0.7454 - recall: 0.6429
# Epoch 35/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7778 - precision: 0.7454 - recall: 0.6429
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.7574 - precision: 0.7215 - recall: 0.6032
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.7737 - precision: 0.7453 - recall: 0.6270
# Epoch 38/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4986 - accuracy: 0.7625 - precision: 0.7316 - recall: 0.6058
# Epoch 39/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4935 - accuracy: 0.7808 - precision: 0.7508 - recall: 0.6455
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4847 - accuracy: 0.7645 - precision: 0.7234 - recall: 0.6296
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4865 - accuracy: 0.7900 - precision: 0.7638 - recall: 0.6587
# Epoch 42/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7819 - precision: 0.7426 - recall: 0.6640
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7819 - precision: 0.7470 - recall: 0.6561
# Epoch 44/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7768 - precision: 0.7416 - recall: 0.6455
# Epoch 45/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4901 - accuracy: 0.7747 - precision: 0.7386 - recall: 0.6429
# Epoch 46/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4894 - accuracy: 0.7655 - precision: 0.7312 - recall: 0.6190
# Epoch 47/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4796 - accuracy: 0.7757 - precision: 0.7532 - recall: 0.6217
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4825 - accuracy: 0.7757 - precision: 0.7394 - recall: 0.6455
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4969 - accuracy: 0.7686 - precision: 0.7309 - recall: 0.6323
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4816 - accuracy: 0.7706 - precision: 0.7413 - recall: 0.6217
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7757 - precision: 0.7500 - recall: 0.6270
# Epoch 52/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4965 - accuracy: 0.7645 - precision: 0.7363 - recall: 0.6058
# Epoch 53/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4745 - accuracy: 0.7829 - precision: 0.7448 - recall: 0.6640
# Epoch 54/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7819 - precision: 0.7645 - recall: 0.6270
# Epoch 55/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7686 - precision: 0.7492 - recall: 0.6005
# Epoch 56/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4751 - accuracy: 0.7829 - precision: 0.7523 - recall: 0.6508
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.7849 - precision: 0.7554 - recall: 0.6534
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4713 - accuracy: 0.7819 - precision: 0.7455 - recall: 0.6587
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4905 - accuracy: 0.7798 - precision: 0.7470 - recall: 0.6481
# Epoch 60/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4832 - accuracy: 0.7696 - precision: 0.7390 - recall: 0.6217
# Epoch 61/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4814 - accuracy: 0.7717 - precision: 0.7421 - recall: 0.6243
# Epoch 62/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7849 - precision: 0.7569 - recall: 0.6508
# Epoch 63/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4748 - accuracy: 0.7829 - precision: 0.7603 - recall: 0.6376
# Epoch 64/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7849 - precision: 0.7523 - recall: 0.6587
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4836 - accuracy: 0.7768 - precision: 0.7416 - recall: 0.6455
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.7859 - precision: 0.7530 - recall: 0.6614
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4801 - accuracy: 0.7778 - precision: 0.7439 - recall: 0.6455
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4698 - accuracy: 0.7819 - precision: 0.7500 - recall: 0.6508
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4822 - accuracy: 0.7717 - precision: 0.7377 - recall: 0.6323
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4867 - accuracy: 0.7686 - precision: 0.7382 - recall: 0.6190
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4707 - accuracy: 0.7931 - precision: 0.7660 - recall: 0.6667
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.7890 - precision: 0.7680 - recall: 0.6481
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.7645 - precision: 0.7248 - recall: 0.6270
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.7768 - precision: 0.7446 - recall: 0.6402
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.7839 - precision: 0.7594 - recall: 0.6429
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4568 - accuracy: 0.7900 - precision: 0.7638 - recall: 0.6587
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.7778 - precision: 0.7469 - recall: 0.6402
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4643 - accuracy: 0.7798 - precision: 0.7531 - recall: 0.6376
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7819 - precision: 0.7595 - recall: 0.6349
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4701 - accuracy: 0.7920 - precision: 0.7669 - recall: 0.6614
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.7961 - precision: 0.7713 - recall: 0.6693
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.7870 - precision: 0.7600 - recall: 0.6534
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4565 - accuracy: 0.7870 - precision: 0.7538 - recall: 0.6640
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4665 - accuracy: 0.7798 - precision: 0.7596 - recall: 0.6270
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4737 - accuracy: 0.7849 - precision: 0.7651 - recall: 0.6376
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4646 - accuracy: 0.7880 - precision: 0.7724 - recall: 0.6376
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4606 - accuracy: 0.7961 - precision: 0.7764 - recall: 0.6614
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.7931 - precision: 0.7814 - recall: 0.6429
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7971 - precision: 0.7878 - recall: 0.6481
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.7880 - precision: 0.7656 - recall: 0.6481
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4618 - accuracy: 0.7941 - precision: 0.7604 - recall: 0.6799
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4587 - accuracy: 0.7951 - precision: 0.7757 - recall: 0.6587
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4587 - accuracy: 0.7900 - precision: 0.7671 - recall: 0.6534
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.8084 - precision: 0.7879 - recall: 0.6878
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.7859 - precision: 0.7658 - recall: 0.6402
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.7808 - precision: 0.7539 - recall: 0.6402
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.7880 - precision: 0.7742 - recall: 0.6349
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4649 - accuracy: 0.7961 - precision: 0.7853 - recall: 0.6481
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4581 - accuracy: 0.7971 - precision: 0.7934 - recall: 0.6402
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.7992 - precision: 0.8047 - recall: 0.6323

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.4734 - accuracy: 0.7982 - precision: 0.7979 - recall: 0.6148 - 229ms/epoch - 21ms/step
# Loss: 0.4734460711479187, Accuracy: 0.7981651425361633, Precision: 0.7978723645210266, Recall: 0.6147540807723999

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[186  19]
#  [ 47  75]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       205
#            1       0.80      0.61      0.69       122
#
#     accuracy                           0.80       327
#    macro avg       0.80      0.76      0.77       327
# weighted avg       0.80      0.80      0.79       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod1_opt2.keras')
