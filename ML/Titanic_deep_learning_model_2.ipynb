# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

input_dim = input_dim = X_train.shape[1]

def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=input_dim))

    # Add Dropout layer
    nn_model.add(tf.keras.layers.Dropout(0.5)) 

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 2)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
   
    # Add final layer with sigmoid activation function
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy","Precision","Recall"])

    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Initialize EarlyStopping callback to monitor the validation loss
# Training will stop if the validation loss doesn't improve for 3 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Trial 60 Complete [00h 00m 04s]
# val_accuracy: 0.7339449524879456
#
# Best val_accuracy So Far: 0.78899085521698
# Total elapsed time: 00h 02m 19s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 1,
#  'num_layers': 2,
#  'units_0': 3,
#  'units_1': 9,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
#  dropout (Dropout)           (None, 1)                 0
#
#  dense_1 (Dense)             (None, 3)                 6
#
#  dense_2 (Dense)             (None, 9)                 36
#
#  dense_3 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 61 (244.00 Byte)
# Trainable params: 61 (244.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 1ms/step - loss: 0.6060 - accuracy: 0.7013 - precision: 0.7545 - recall: 0.3333
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6069 - accuracy: 0.7013 - precision: 0.7673 - recall: 0.3228
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6050 - accuracy: 0.7003 - precision: 0.7561 - recall: 0.3280
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6103 - accuracy: 0.6942 - precision: 0.7167 - recall: 0.3413
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.7176 - precision: 0.7853 - recall: 0.3677
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.7146 - precision: 0.7663 - recall: 0.3730
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6005 - accuracy: 0.7013 - precision: 0.7457 - recall: 0.3413
# Epoch 8/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.7105 - precision: 0.7765 - recall: 0.3492
# Epoch 9/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5984 - accuracy: 0.7044 - precision: 0.7444 - recall: 0.3545
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.7136 - precision: 0.7650 - recall: 0.3704
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5949 - accuracy: 0.7085 - precision: 0.7674 - recall: 0.3492
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5832 - accuracy: 0.7176 - precision: 0.7730 - recall: 0.3783
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5972 - accuracy: 0.7085 - precision: 0.7556 - recall: 0.3598
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7217 - precision: 0.7869 - recall: 0.3810
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.6942 - precision: 0.7349 - recall: 0.3228
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.7054 - precision: 0.7665 - recall: 0.3386
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.7054 - precision: 0.7764 - recall: 0.3307
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5934 - accuracy: 0.7074 - precision: 0.7692 - recall: 0.3439
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5821 - accuracy: 0.7166 - precision: 0.7809 - recall: 0.3677
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.7176 - precision: 0.7821 - recall: 0.3704
# Epoch 21/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7146 - precision: 0.7722 - recall: 0.3677
# Epoch 22/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.7074 - precision: 0.7571 - recall: 0.3545
# Epoch 23/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6010 - accuracy: 0.6993 - precision: 0.7546 - recall: 0.3254
# Epoch 24/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5603 - accuracy: 0.7380 - precision: 0.8380 - recall: 0.3968
# Epoch 25/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5946 - accuracy: 0.7034 - precision: 0.7574 - recall: 0.3386
# Epoch 26/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5939 - accuracy: 0.7054 - precision: 0.7543 - recall: 0.3492
# Epoch 27/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5986 - accuracy: 0.7003 - precision: 0.7561 - recall: 0.3280
# Epoch 28/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5746 - accuracy: 0.7227 - precision: 0.8081 - recall: 0.3677
# Epoch 29/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5888 - accuracy: 0.7085 - precision: 0.7911 - recall: 0.3307
# Epoch 30/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.7044 - precision: 0.7391 - recall: 0.3598
# Epoch 31/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5902 - accuracy: 0.7074 - precision: 0.7898 - recall: 0.3280
# Epoch 32/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5988 - accuracy: 0.6972 - precision: 0.7368 - recall: 0.3333
# Epoch 33/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5949 - accuracy: 0.7023 - precision: 0.7722 - recall: 0.3228
# Epoch 34/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5830 - accuracy: 0.7125 - precision: 0.7791 - recall: 0.3545
# Epoch 35/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.7115 - precision: 0.7746 - recall: 0.3545
# Epoch 36/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.6891 - precision: 0.7267 - recall: 0.3095
# Epoch 37/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.7034 - precision: 0.7636 - recall: 0.3333
# Epoch 38/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.6962 - precision: 0.7381 - recall: 0.3280
# Epoch 39/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.7176 - precision: 0.7853 - recall: 0.3677
# Epoch 40/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5900 - accuracy: 0.7074 - precision: 0.7725 - recall: 0.3413
# Epoch 41/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5864 - accuracy: 0.7105 - precision: 0.7765 - recall: 0.3492
# Epoch 42/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5857 - accuracy: 0.7125 - precision: 0.7759 - recall: 0.3571
# Epoch 43/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5901 - accuracy: 0.7085 - precision: 0.7949 - recall: 0.3280
# Epoch 44/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.7074 - precision: 0.7661 - recall: 0.3466
# Epoch 45/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.6993 - precision: 0.7643 - recall: 0.3175
# Epoch 46/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5970 - accuracy: 0.7003 - precision: 0.7625 - recall: 0.3228
# Epoch 47/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5823 - accuracy: 0.7085 - precision: 0.7840 - recall: 0.3360
# Epoch 48/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.7105 - precision: 0.7866 - recall: 0.3413
# Epoch 49/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5723 - accuracy: 0.7217 - precision: 0.8035 - recall: 0.3677
# Epoch 50/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5900 - accuracy: 0.7044 - precision: 0.7418 - recall: 0.3571
# Epoch 51/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5869 - accuracy: 0.7085 - precision: 0.7738 - recall: 0.3439
# Epoch 52/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5734 - accuracy: 0.7166 - precision: 0.8012 - recall: 0.3519
# Epoch 53/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5820 - accuracy: 0.7125 - precision: 0.7963 - recall: 0.3413
# Epoch 54/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.7003 - precision: 0.7308 - recall: 0.3519
# Epoch 55/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5868 - accuracy: 0.7054 - precision: 0.7764 - recall: 0.3307
# Epoch 56/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5904 - accuracy: 0.7125 - precision: 0.7963 - recall: 0.3413
# Epoch 57/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.7023 - precision: 0.7945 - recall: 0.3069
# Epoch 58/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.7034 - precision: 0.7702 - recall: 0.3280
# Epoch 59/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.7115 - precision: 0.7568 - recall: 0.3704
# Epoch 60/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.7156 - precision: 0.7964 - recall: 0.3519
# Epoch 61/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.7013 - precision: 0.7607 - recall: 0.3280
# Epoch 62/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.7095 - precision: 0.7751 - recall: 0.3466
# Epoch 63/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5907 - accuracy: 0.7095 - precision: 0.7853 - recall: 0.3386
# Epoch 64/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5869 - accuracy: 0.7074 - precision: 0.7630 - recall: 0.3492
# Epoch 65/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5641 - accuracy: 0.7288 - precision: 0.8373 - recall: 0.3677
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5932 - accuracy: 0.6972 - precision: 0.7832 - recall: 0.2963
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7197 - precision: 0.8411 - recall: 0.3360
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.7064 - precision: 0.7586 - recall: 0.3492
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5876 - accuracy: 0.7085 - precision: 0.7771 - recall: 0.3413
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5883 - accuracy: 0.7105 - precision: 0.8092 - recall: 0.3254
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5695 - accuracy: 0.7217 - precision: 0.7933 - recall: 0.3757
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5713 - accuracy: 0.7125 - precision: 0.7759 - recall: 0.3571
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.6983 - precision: 0.7500 - recall: 0.3254
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.7095 - precision: 0.8079 - recall: 0.3228
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5835 - accuracy: 0.7074 - precision: 0.7974 - recall: 0.3228
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5808 - accuracy: 0.7064 - precision: 0.7848 - recall: 0.3280
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5672 - accuracy: 0.7197 - precision: 0.7943 - recall: 0.3677
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7166 - precision: 0.8247 - recall: 0.3360
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5778 - accuracy: 0.7176 - precision: 0.7988 - recall: 0.3571
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7146 - precision: 0.8025 - recall: 0.3439
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5932 - accuracy: 0.6993 - precision: 0.7943 - recall: 0.2963
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5821 - accuracy: 0.7064 - precision: 0.7848 - recall: 0.3280
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5711 - accuracy: 0.7197 - precision: 0.8366 - recall: 0.3386
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5732 - accuracy: 0.7187 - precision: 0.8036 - recall: 0.3571
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5876 - accuracy: 0.7074 - precision: 0.8054 - recall: 0.3175
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5903 - accuracy: 0.7003 - precision: 0.7593 - recall: 0.3254
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5694 - accuracy: 0.7268 - precision: 0.8481 - recall: 0.3545
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5681 - accuracy: 0.7176 - precision: 0.8301 - recall: 0.3360
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.7013 - precision: 0.7576 - recall: 0.3307
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5693 - accuracy: 0.7176 - precision: 0.8176 - recall: 0.3439
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5875 - accuracy: 0.7064 - precision: 0.7778 - recall: 0.3333
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5726 - accuracy: 0.7105 - precision: 0.7831 - recall: 0.3439
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5729 - accuracy: 0.7207 - precision: 0.8467 - recall: 0.3360
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5795 - accuracy: 0.7125 - precision: 0.8243 - recall: 0.3228
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.7125 - precision: 0.7927 - recall: 0.3439
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5906 - accuracy: 0.7044 - precision: 0.7973 - recall: 0.3122
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.7146 - precision: 0.8267 - recall: 0.3280
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5820 - accuracy: 0.7054 - precision: 0.7834 - recall: 0.3254
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5955 - accuracy: 0.6952 - precision: 0.7724 - recall: 0.2963
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7125 - precision: 0.8243 - recall: 0.3228

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.5585 - accuracy: 0.7401 - precision: 0.9744 - recall: 0.3115 - 236ms/epoch - 21ms/step
# Loss: 0.5585038065910339, Accuracy: 0.7400611639022827, Precision: 0.9743589758872986, Recall: 0.31147539615631104

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[204   1]
#  [ 84  38]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       205
#            1       0.97      0.31      0.47       122
#
#     accuracy                           0.74       327
#    macro avg       0.84      0.65      0.65       327
# weighted avg       0.81      0.74      0.69       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod2.keras')
