# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the CSV file from the Dataset folder into a Pandas DataFrame
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/Base_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id    Title                          First Name Last Name  \
# 0             1     Miss                    Elisabeth Walton     Allen
# 1             2   Master                       Hudson Trevor   Allison
# 2             3     Miss                       Helen Loraine   Allison
# 3             4       Mr             Hudson Joshua Creighton   Allison
# 4             5      Mrs   Hudson J C (Bessie Waldo Daniels)   Allison
#
#       Sex      Age  Sibling/Spouse Aboard  Parent/Children Aboard  \
# 0  female  29.0000                      0                       0
# 1    male   0.9167                      1                       2
# 2  female   2.0000                      1                       2
# 3    male  30.0000                      1                       2
# 4  female  25.0000                      1                       2
#
#    Passenger Class      Fare Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                S             2           S
# 1                1  151.5500                S            11           S
# 2                1  151.5500                S           DNS         BNR
# 3                1  151.5500                S           DNS         135
# 4                1  151.5500                S           DNS         BNR
#
#    Survived age_group  family_size
# 0         1    Adults            0
# 1         1  Children            3
# 2         0  Children            3
# 3         0    Adults            3
# 4         0    Adults            3

# %%
# Print DataFrame information to ensure no null values and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Title                   1308 non-null   object
#  2   First Name              1308 non-null   object
#  3   Last Name               1308 non-null   object
#  4   Sex                     1308 non-null   object
#  5   Age                     1308 non-null   float64
#  6   Sibling/Spouse Aboard   1308 non-null   int64
#  7   Parent/Children Aboard  1308 non-null   int64
#  8   Passenger Class         1308 non-null   int64
#  9   Fare                    1308 non-null   float64
#  10  Embarkation Port        1308 non-null   object
#  11  Survival Boat           1308 non-null   object
#  12  Body Number             1308 non-null   object
#  13  Survived                1308 non-null   int64
#  14  age_group               1308 non-null   object
#  15  family_size             1308 non-null   int64
# dtypes: float64(2), int64(6), object(8)
# memory usage: 163.6+ KB

# %%
# Preprocessing for features which are currently objects
labelencoder_X = LabelEncoder()
dfSurvivals["Title"] = labelencoder_X.fit_transform(dfSurvivals["Title"])
dfSurvivals["Last Name"] = labelencoder_X.fit_transform(dfSurvivals["Last Name"])
dfSurvivals["Sex"] = labelencoder_X.fit_transform(dfSurvivals["Sex"])
dfSurvivals["Embarkation Port"] = labelencoder_X.fit_transform(dfSurvivals["Embarkation Port"])
dfSurvivals["age_group"] = labelencoder_X.fit_transform(dfSurvivals["age_group"])

# %%
# Drop columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'First Name', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#    Title  Last Name  Sex      Age  Sibling/Spouse Aboard  \
# 0      9         15    0  29.0000                      0
# 1      8         16    1   0.9167                      1
# 2      9         16    0   2.0000                      1
# 3     12         16    1  30.0000                      1
# 4     13         16    0  25.0000                      1
#
#    Parent/Children Aboard  Passenger Class      Fare  Embarkation Port  \
# 0                       0                1  211.3375                 2
# 1                       2                1  151.5500                 2
# 2                       2                1  151.5500                 2
# 3                       2                1  151.5500                 2
# 4                       2                1  151.5500                 2
#
#    Survived  age_group  family_size
# 0         1          0            0
# 1         1          1            3
# 2         0          1            3
# 3         0          0            3
# 4         0          0            3

# %%
# Ensure all columns are numerical
dfSurvivals.dtypes
# Out:
# Title                       int32
# Last Name                   int32
# Sex                         int32
# Age                       float64
# Sibling/Spouse Aboard       int64
# Parent/Children Aboard      int64
# Passenger Class             int64
# Fare                      float64
# Embarkation Port            int32
# Survived                    int64
# age_group                   int32
# family_size                 int64
# dtype: object

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Get the number of input features
input_dim = X_train.shape[1]

# Function to create and compile the neural network
def create_model(hp):
    
    # Create a new model
    nn_model = tf.keras.models.Sequential()
    
    # Choose activation function for hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Add first hidden layer with hyperparameter-tuned settings
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1, 
        max_value=10, 
        step=2), 
        activation=activation, 
        input_dim=input_dim))
    
    # Add second hidden layer with 10 neurons
    nn_model.add(tf.keras.layers.Dense(units=10, activation=activation))
    
    # Add output layer for binary classification
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "Precision", "Recall"]) 
    
    # Return compiled model
    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 21 Complete [00h 00m 02s]
# val_accuracy: 0.6269113421440125
#
# Best val_accuracy So Far: 0.7737002968788147
# Total elapsed time: 00h 00m 42s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0013'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 108
#
#  dense_1 (Dense)             (None, 10)                100
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 219 (876.00 Byte)
# Trainable params: 219 (876.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 2ms/step - loss: 0.4471 - accuracy: 0.7992 - precision: 0.7466 - recall: 0.7249
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4437 - accuracy: 0.7982 - precision: 0.7432 - recall: 0.7275
# Epoch 3/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.8002 - precision: 0.7473 - recall: 0.7275
# Epoch 4/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0.8073 - precision: 0.7662 - recall: 0.7196
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4351 - accuracy: 0.8084 - precision: 0.7654 - recall: 0.7249
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4325 - accuracy: 0.8084 - precision: 0.7654 - recall: 0.7249
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4301 - accuracy: 0.8114 - precision: 0.7734 - recall: 0.7222
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8124 - precision: 0.7771 - recall: 0.7196
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8145 - precision: 0.7816 - recall: 0.7196
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4249 - accuracy: 0.8145 - precision: 0.7849 - recall: 0.7143
# Epoch 11/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4237 - accuracy: 0.8155 - precision: 0.7889 - recall: 0.7116
# Epoch 12/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8155 - precision: 0.7872 - recall: 0.7143
# Epoch 13/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4206 - accuracy: 0.8145 - precision: 0.7882 - recall: 0.7090
# Epoch 14/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.8165 - precision: 0.7912 - recall: 0.7116
# Epoch 15/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4185 - accuracy: 0.8165 - precision: 0.7912 - recall: 0.7116
# Epoch 16/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8186 - precision: 0.7994 - recall: 0.7063
# Epoch 17/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8196 - precision: 0.8000 - recall: 0.7090
# Epoch 18/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4146 - accuracy: 0.8206 - precision: 0.8042 - recall: 0.7063
# Epoch 19/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4134 - accuracy: 0.8247 - precision: 0.8065 - recall: 0.7169
# Epoch 20/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8257 - precision: 0.8071 - recall: 0.7196
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8491 - precision: 0.8549 - recall: 0.7328
# Epoch 66/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8512 - precision: 0.8602 - recall: 0.7328
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3841 - accuracy: 0.8491 - precision: 0.8571 - recall: 0.7302
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8491 - precision: 0.8549 - recall: 0.7328
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3838 - accuracy: 0.8491 - precision: 0.8571 - recall: 0.7302
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3827 - accuracy: 0.8491 - precision: 0.8549 - recall: 0.7328
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3832 - accuracy: 0.8491 - precision: 0.8571 - recall: 0.7302
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3823 - accuracy: 0.8502 - precision: 0.8598 - recall: 0.7302
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8502 - precision: 0.8598 - recall: 0.7302
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8481 - precision: 0.8589 - recall: 0.7249
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8491 - precision: 0.8639 - recall: 0.7222
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8461 - precision: 0.8536 - recall: 0.7249
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8481 - precision: 0.8589 - recall: 0.7249
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.8502 - precision: 0.8598 - recall: 0.7302
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8491 - precision: 0.8594 - recall: 0.7275
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3793 - accuracy: 0.8461 - precision: 0.8536 - recall: 0.7249
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3790 - accuracy: 0.8461 - precision: 0.8536 - recall: 0.7249
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3791 - accuracy: 0.8491 - precision: 0.8616 - recall: 0.7249
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3787 - accuracy: 0.8491 - precision: 0.8639 - recall: 0.7222
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3779 - accuracy: 0.8512 - precision: 0.8648 - recall: 0.7275
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3786 - accuracy: 0.8471 - precision: 0.8497 - recall: 0.7328
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 0.8502 - precision: 0.8667 - recall: 0.7222
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3770 - accuracy: 0.8512 - precision: 0.8625 - recall: 0.7302
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3774 - accuracy: 0.8502 - precision: 0.8644 - recall: 0.7249
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3763 - accuracy: 0.8491 - precision: 0.8571 - recall: 0.7302
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8481 - precision: 0.8567 - recall: 0.7275
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3753 - accuracy: 0.8502 - precision: 0.8667 - recall: 0.7222
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8481 - precision: 0.8589 - recall: 0.7249
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8502 - precision: 0.8690 - recall: 0.7196
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3748 - accuracy: 0.8502 - precision: 0.8576 - recall: 0.7328
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3747 - accuracy: 0.8461 - precision: 0.8626 - recall: 0.7143
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.8512 - precision: 0.8625 - recall: 0.7302
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3738 - accuracy: 0.8502 - precision: 0.8621 - recall: 0.7275
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.8491 - precision: 0.8686 - recall: 0.7169
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3732 - accuracy: 0.8491 - precision: 0.8662 - recall: 0.7196
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3726 - accuracy: 0.8512 - precision: 0.8694 - recall: 0.7222

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.5010 - accuracy: 0.7768 - precision: 0.7426 - recall: 0.6148 - 229ms/epoch - 21ms/step
# Loss: 0.5009827017784119, Accuracy: 0.7767584323883057, Precision: 0.7425742745399475, Recall: 0.6147540807723999

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[179  26]
#  [ 47  75]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       205
#            1       0.74      0.61      0.67       122
#
#     accuracy                           0.78       327
#    macro avg       0.77      0.74      0.75       327
# weighted avg       0.77      0.78      0.77       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod1_reprocessed.keras')
