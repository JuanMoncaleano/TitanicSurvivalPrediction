# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

input_dim = input_dim = X_train.shape[1]

def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=input_dim))

    # Remove Dropout layer
    # nn_model.add(tf.keras.layers.Dropout(0.5)) 
    
    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 2)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
   
    # Add final layer with sigmoid activation function
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy","Precision","Recall"])

    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Initialize EarlyStopping callback to monitor the validation loss
# Training will stop if the validation loss doesn't improve for 3 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Trial 60 Complete [00h 00m 04s]
# val_accuracy: 0.7645260095596313
#
# Best val_accuracy So Far: 0.785932719707489
# Total elapsed time: 00h 02m 16s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'num_layers': 1,
#  'units_0': 9,
#  'units_1': 7,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0042'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 81
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 181 (724.00 Byte)
# Trainable params: 181 (724.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 1ms/step - loss: 0.4430 - accuracy: 0.8073 - precision: 0.7981 - recall: 0.6693
# Epoch 2/100
# Epoch 67/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8410 - precision: 0.8750 - recall: 0.6852
# Epoch 68/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8379 - precision: 0.8662 - recall: 0.6852
# Epoch 69/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8400 - precision: 0.8696 - recall: 0.6878
# Epoch 70/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8359 - precision: 0.8581 - recall: 0.6878
# Epoch 71/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3986 - accuracy: 0.8420 - precision: 0.8780 - recall: 0.6852
# Epoch 72/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905
# Epoch 73/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.8389 - precision: 0.8691 - recall: 0.6852
# Epoch 74/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8410 - precision: 0.8725 - recall: 0.6878
# Epoch 75/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8369 - precision: 0.8586 - recall: 0.6905
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8400 - precision: 0.8746 - recall: 0.6825
# Epoch 77/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8420 - precision: 0.8780 - recall: 0.6852
# Epoch 78/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8349 - precision: 0.8553 - recall: 0.6878
# Epoch 79/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8379 - precision: 0.8638 - recall: 0.6878
# Epoch 80/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8359 - precision: 0.8581 - recall: 0.6878
# Epoch 81/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8349 - precision: 0.8529 - recall: 0.6905
# Epoch 82/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8420 - precision: 0.8754 - recall: 0.6878
# Epoch 83/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8420 - precision: 0.8754 - recall: 0.6878
# Epoch 84/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8420 - precision: 0.8754 - recall: 0.6878
# Epoch 85/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8400 - precision: 0.8696 - recall: 0.6878
# Epoch 86/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8379 - precision: 0.8614 - recall: 0.6905
# Epoch 87/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3962 - accuracy: 0.8400 - precision: 0.8696 - recall: 0.6878
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3967 - accuracy: 0.8440 - precision: 0.8788 - recall: 0.6905
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8359 - precision: 0.8581 - recall: 0.6878
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8410 - precision: 0.8725 - recall: 0.6878
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3957 - accuracy: 0.8389 - precision: 0.8667 - recall: 0.6878
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8420 - precision: 0.8754 - recall: 0.6878
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8389 - precision: 0.8667 - recall: 0.6878
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8400 - precision: 0.8696 - recall: 0.6878
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8410 - precision: 0.8725 - recall: 0.6878
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3960 - accuracy: 0.8410 - precision: 0.8700 - recall: 0.6905
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8430 - precision: 0.8810 - recall: 0.6852
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8400 - precision: 0.8696 - recall: 0.6878
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8430 - precision: 0.8758 - recall: 0.6905
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8379 - precision: 0.8614 - recall: 0.6905

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.4722 - accuracy: 0.7768 - precision: 0.7692 - recall: 0.5738 - 227ms/epoch - 21ms/step
# Loss: 0.4721972644329071, Accuracy: 0.7767584323883057, Precision: 0.7692307829856873, Recall: 0.5737704634666443

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 801us/step
# Confusion Matrix:
# [[184  21]
#  [ 52  70]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83       205
#            1       0.77      0.57      0.66       122
#
#     accuracy                           0.78       327
#    macro avg       0.77      0.74      0.75       327
# weighted avg       0.78      0.78      0.77       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod2_opt1.keras')
