# %% [markdown]
# ### Module Importation and DataFrame Setup

# %%
# Reset the model for re-run
from tensorflow.keras import backend as K
K.clear_session()

# Import dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras_tuner as kt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Read the preprocessed CSV file from the Dataset folder into a Pandas DataFrame (see logistic regression model for preprocessing)
dfSurvivals = pd.read_csv(
    Path("../CSV_OUTPUT/ML_Cleaned_DS_CSV.csv")
)

# %%
# Review the DataFrame
dfSurvivals.head()
# Out:
#    Passenger Id      Age  Sibling/Spouse Abroad  Parent/Children Abroad  \
# 0             1  29.0000                      0                       0
# 1             2   0.9167                      1                       2
# 2             3   2.0000                      1                       2
# 3             4  30.0000                      1                       2
# 4             5  25.0000                      1                       2
#
#    Passenger Class      Fare  Embarkation Port Survival Boat Body Number  \
# 0                1  211.3375                 2             2           S
# 1                1  151.5500                 2            11           S
# 2                1  151.5500                 2           DNS         BNR
# 3                1  151.5500                 2           DNS       135.0
# 4                1  151.5500                 2           DNS         BNR
#
#    Survived  Female  Male
# 0         1     1.0   0.0
# 1         1     0.0   1.0
# 2         0     1.0   0.0
# 3         0     0.0   1.0
# 4         0     1.0   0.0

# %%
# Print DataFrame information to ensure no null values (data cleaned in previous notebook) and check datatypes
dfSurvivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Passenger Id            1308 non-null   int64
#  1   Age                     1308 non-null   float64
#  2   Sibling/Spouse Abroad   1308 non-null   int64
#  3   Parent/Children Abroad  1308 non-null   int64
#  4   Passenger Class         1308 non-null   int64
#  5   Fare                    1308 non-null   float64
#  6   Embarkation Port        1308 non-null   int64
#  7   Survival Boat           1308 non-null   object
#  8   Body Number             1308 non-null   object
#  9   Survived                1308 non-null   int64
#  10  Female                  1308 non-null   float64
#  11  Male                    1308 non-null   float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 122.8+ KB

# %%
# Drop Passenger ID, Survival Boat, and Body Number columns
dfSurvivals = dfSurvivals.drop(['Passenger Id', 'Survival Boat', 'Body Number'], axis=1)
dfSurvivals.head()
# Out:
#        Age  Sibling/Spouse Abroad  Parent/Children Abroad  Passenger Class  \
# 0  29.0000                      0                       0                1
# 1   0.9167                      1                       2                1
# 2   2.0000                      1                       2                1
# 3  30.0000                      1                       2                1
# 4  25.0000                      1                       2                1
#
#        Fare  Embarkation Port  Survived  Female  Male
# 0  211.3375                 2         1     1.0   0.0
# 1  151.5500                 2         1     0.0   1.0
# 2  151.5500                 2         0     1.0   0.0
# 3  151.5500                 2         0     0.0   1.0
# 4  151.5500                 2         0     1.0   0.0

# %% [markdown]
# ### Split the data into X and y and then into testing and training sets

# %%
# Split the data into X (features) and y (target)

# Set the y variable, which is the target
y = dfSurvivals['Survived']

# Set the X variable, which includes all features escept the target
X = dfSurvivals.drop(columns=['Survived'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train, and Evaluate the Model

# %%
# Get the number of input features
input_dim = X_train.shape[1]

# Function to create and compile the neural network
def create_model(hp):
    
    # Create a new model
    nn_model = tf.keras.models.Sequential()
    
    # Choose activation function for hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Add first hidden layer with hyperparameter-tuned settings
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units', 
        min_value=1, 
        max_value=10, 
        step=2), 
        activation=activation,
        
        # Removed L2 regularization
        # kernel_regularizer=tf.keras.regularizers.l2(0.01),
        input_dim=input_dim))
    
    # Removed Dropout layer
    # nn_model.add(tf.keras.layers.Dropout(0.5))
    
    # Add second hidden layer with 10 neurons
    nn_model.add(tf.keras.layers.Dense(units=10, activation=activation))
    
    # Add output layer for binary classification
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "Precision", "Recall"]) 
    
    # Return compiled model
    return nn_model

# %%
# Set up the kerastuner then allow it to search for best hyperparameters
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    overwrite=True)

# Initialize EarlyStopping callback to monitor the validation loss
# Training will stop if the validation loss doesn't improve for 3 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Perform hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Trial 21 Complete [00h 00m 02s]
# val_accuracy: 0.7064220309257507
#
# Best val_accuracy So Far: 0.7767584323883057
# Total elapsed time: 00h 00m 44s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the hyperparameters of the best model
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 5,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0014'}

# %%
# Get the best model
best_model = tuner.get_best_models(1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 45
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 226 (904.00 Byte)
# Trainable params: 226 (904.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
fit_model = best_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 1ms/step - loss: 0.4427 - accuracy: 0.8043 - precision: 0.7672 - recall: 0.7063
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3987 - accuracy: 0.8359 - precision: 0.8581 - recall: 0.6878
# Epoch 89/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.8328 - precision: 0.8567 - recall: 0.6799
# Epoch 90/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8369 - precision: 0.8586 - recall: 0.6905
# Epoch 91/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 92/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.8369 - precision: 0.8586 - recall: 0.6905
# Epoch 93/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8379 - precision: 0.8567 - recall: 0.6958
# Epoch 94/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8359 - precision: 0.8557 - recall: 0.6905
# Epoch 95/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8379 - precision: 0.8590 - recall: 0.6931
# Epoch 96/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8349 - precision: 0.8600 - recall: 0.6825
# Epoch 97/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8369 - precision: 0.8539 - recall: 0.6958
# Epoch 98/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8359 - precision: 0.8629 - recall: 0.6825
# Epoch 99/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8369 - precision: 0.8562 - recall: 0.6931
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3983 - accuracy: 0.8379 - precision: 0.8590 - recall: 0.6931

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_precision, model_recall = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# 11/11 - 0s - loss: 0.4716 - accuracy: 0.7645 - precision: 0.7473 - recall: 0.5574 - 234ms/epoch - 21ms/step
# Loss: 0.4715633690357208, Accuracy: 0.7645260095596313, Precision: 0.7472527623176575, Recall: 0.5573770403862

# %%
# Use the model to make predictions on test data
y_pred_prob = best_model.predict(X_test_scaled).flatten()
y_pred = [1 if prob >= 0.5 else 0 for prob in y_pred_prob]

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# 11/11 [==============================] - 0s 901us/step
# Confusion Matrix:
# [[182  23]
#  [ 54  68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       205
#            1       0.75      0.56      0.64       122
#
#     accuracy                           0.76       327
#    macro avg       0.76      0.72      0.73       327
# weighted avg       0.76      0.76      0.76       327

# %%
# Export our model to keras file
best_model.save('OUTPUT/Titanic_survival_mod1_opt3.keras')
